# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %%
data = pd.read_excel('seven_major_felony_offenses_2000_2018.xls')

# %%
data.head(20)
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                         Seven Major Felony Offenses         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                             OFFENSE      2000.0      2001.0
# 4                     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0
# 5                                                RAPE      2068.0      1981.0
# 6                                             ROBBERY     32562.0     28202.0
# 7                                      FELONY ASSAULT     25924.0     23453.0
# 8                                            BURGLARY     38352.0     32763.0
# 9                                       GRAND LARCENY     49631.0     46329.0
# 10                     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      4
# Unnamed: 1     10
# Unnamed: 2     10
# Unnamed: 3     10
# Unnamed: 4     10
# Unnamed: 5     10
# Unnamed: 6     10
# Unnamed: 7     10
# Unnamed: 8     10
# Unnamed: 9     10
# Unnamed: 10    10
# Unnamed: 11    10
# Unnamed: 12    10
# Unnamed: 13    10
# Unnamed: 14    10
# Unnamed: 15    10
# Unnamed: 16    10
# Unnamed: 17    10
# Unnamed: 18    10
# Unnamed: 19    10
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
df = data.copy()

# %%
df
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                         Seven Major Felony Offenses         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                             OFFENSE      2000.0      2001.0
# 4                     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0
# 5                                                RAPE      2068.0      1981.0
# 6                                             ROBBERY     32562.0     28202.0
# 7                                      FELONY ASSAULT     25924.0     23453.0
# 8                                            BURGLARY     38352.0     32763.0
# 9                                       GRAND LARCENY     49631.0     46329.0
# 10                     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0
# ...

# %%
df = df.drop([df.index[12]])

# %%
df
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                         Seven Major Felony Offenses         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                             OFFENSE      2000.0      2001.0
# 4                     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0
# 5                                                RAPE      2068.0      1981.0
# 6                                             ROBBERY     32562.0     28202.0
# 7                                      FELONY ASSAULT     25924.0     23453.0
# 8                                            BURGLARY     38352.0     32763.0
# 9                                       GRAND LARCENY     49631.0     46329.0
# 10                     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0
# ...

# %%
df = df.drop([df.index[13],df.index[14],df.index[15],df.index[16],df.index[17]])

# %%
df
# Out:
#                            Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0         Seven Major Felony Offenses         NaN         NaN         NaN
# 1                                 NaN         NaN         NaN         NaN
# 2                                 NaN         NaN         NaN         NaN
# 3                             OFFENSE      2000.0      2001.0      2002.0
# 4     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0       587.0
# 5                                RAPE      2068.0      1981.0      2144.0
# 6                             ROBBERY     32562.0     28202.0     27229.0
# 7                      FELONY ASSAULT     25924.0     23453.0     21147.0
# 8                            BURGLARY     38352.0     32763.0     31275.0
# 9                       GRAND LARCENY     49631.0     46329.0     45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0     26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES    184652.0    162908.0    154809.0
# ...

# %%
df = df.drop([df.index[0],df.index[1],df.index[2]])

# %%
df
# Out:
#                            Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 3                             OFFENSE      2000.0      2001.0      2002.0
# 4     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0       587.0
# 5                                RAPE      2068.0      1981.0      2144.0
# 6                             ROBBERY     32562.0     28202.0     27229.0
# 7                      FELONY ASSAULT     25924.0     23453.0     21147.0
# 8                            BURGLARY     38352.0     32763.0     31275.0
# 9                       GRAND LARCENY     49631.0     46329.0     45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0     26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES    184652.0    162908.0    154809.0
# 13                                NaN         NaN         NaN         NaN
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 3       2003.0      2004.0      2005.0      2006.0      2007.0      2008.0
# ...

# %%
df
# Out:
#                            Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 3                             OFFENSE      2000.0      2001.0      2002.0
# 4     MURDER & NON-NEGL. MANSLAUGHTER       673.0       649.0       587.0
# 5                                RAPE      2068.0      1981.0      2144.0
# 6                             ROBBERY     32562.0     28202.0     27229.0
# 7                      FELONY ASSAULT     25924.0     23453.0     21147.0
# 8                            BURGLARY     38352.0     32763.0     31275.0
# 9                       GRAND LARCENY     49631.0     46329.0     45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE     35442.0     29531.0     26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES    184652.0    162908.0    154809.0
# 13                                NaN         NaN         NaN         NaN
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 3       2003.0      2004.0      2005.0      2006.0      2007.0      2008.0
# ...

# %%
df = df.rename(columns = {'Unnamed: 0':'Offense',
                          'Unnamed: 1':'Year 2000',
                          'Unnamed: 2':'Year 2001',
                          'Unnamed: 3':'Year 2002',
                          'Unnamed: 4':'Year 2003',
                          'Unnamed: 5':'Year 2004',
                          'Unnamed: 6':'Year 2005',
                          'Unnamed: 7':'Year 2006',
                          'Unnamed: 8':'Year 2007',
                          'Unnamed: 9':'Year 2008',
                          'Unnamed: 10':'Year 2009',
                          'Unnamed: 11':'Year 2010',
                          'Unnamed: 12':'Year 2011',
                          'Unnamed: 13':'Year 2012',
                          'Unnamed: 14':'Year 2013',
                          'Unnamed: 15':'Year 2014',
                          'Unnamed: 16':'Year 2015',
                          'Unnamed: 17':'Year 2016',
                          'Unnamed: 18':'Year 2017',
                         'Unnamed: 19':'Year 2018'})

# %%
df
# Out:
#                               Offense  Year 2000  Year 2001  Year 2002  \
# 3                             OFFENSE     2000.0     2001.0     2002.0
# 4     MURDER & NON-NEGL. MANSLAUGHTER      673.0      649.0      587.0
# 5                                RAPE     2068.0     1981.0     2144.0
# 6                             ROBBERY    32562.0    28202.0    27229.0
# 7                      FELONY ASSAULT    25924.0    23453.0    21147.0
# 8                            BURGLARY    38352.0    32763.0    31275.0
# 9                       GRAND LARCENY    49631.0    46329.0    45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE    35442.0    29531.0    26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES   184652.0   162908.0   154809.0
# 13                                NaN        NaN        NaN        NaN
#
#     Year 2003  Year 2004  Year 2005  Year 2006  Year 2007  Year 2008  \
# 3      2003.0     2004.0     2005.0     2006.0     2007.0     2008.0
# ...

# %%
df.columns
# Out:
# Index(['Offense', 'Year 2000', 'Year 2001', 'Year 2002', 'Year 2003',
#        'Year 2004', 'Year 2005', 'Year 2006', 'Year 2007', 'Year 2008',
#        'Year 2009', 'Year 2010', 'Year 2011', 'Year 2012', 'Year 2013',
#        'Year 2014', 'Year 2015', 'Year 2016', 'Year 2017', 'Year 2018'],
#       dtype='object')

# %%
df = df.drop([df.index[0]])

# %%
df
# Out:
#                               Offense  Year 2000  Year 2001  Year 2002  \
# 4     MURDER & NON-NEGL. MANSLAUGHTER      673.0      649.0      587.0
# 5                                RAPE     2068.0     1981.0     2144.0
# 6                             ROBBERY    32562.0    28202.0    27229.0
# 7                      FELONY ASSAULT    25924.0    23453.0    21147.0
# 8                            BURGLARY    38352.0    32763.0    31275.0
# 9                       GRAND LARCENY    49631.0    46329.0    45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE    35442.0    29531.0    26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES   184652.0   162908.0   154809.0
# 13                                NaN        NaN        NaN        NaN
#
#     Year 2003  Year 2004  Year 2005  Year 2006  Year 2007  Year 2008  \
# 4       597.0      570.0      539.0      596.0      496.0      523.0
# 5      2070.0     1905.0     1858.0     1525.0     1351.0     1299.0
# ...

# %%
df = df.drop([df.index[8]])

# %%
df
# Out:
#                               Offense  Year 2000  Year 2001  Year 2002  \
# 4     MURDER & NON-NEGL. MANSLAUGHTER      673.0      649.0      587.0
# 5                                RAPE     2068.0     1981.0     2144.0
# 6                             ROBBERY    32562.0    28202.0    27229.0
# 7                      FELONY ASSAULT    25924.0    23453.0    21147.0
# 8                            BURGLARY    38352.0    32763.0    31275.0
# 9                       GRAND LARCENY    49631.0    46329.0    45771.0
# 10     GRAND LARCENY OF MOTOR VEHICLE    35442.0    29531.0    26656.0
# 11  TOTAL SEVEN MAJOR FELONY OFFENSES   184652.0   162908.0   154809.0
#
#     Year 2003  Year 2004  Year 2005  Year 2006  Year 2007  Year 2008  \
# 4       597.0      570.0      539.0      596.0      496.0      523.0
# 5      2070.0     1905.0     1858.0     1525.0     1351.0     1299.0
# 6     25989.0    24373.0    24722.0    23739.0    21809.0    22401.0
# ...

# %%
df.to_csv('felony_offence.csv')
